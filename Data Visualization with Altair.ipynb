# %% [markdown]
# import altair as alt
# import pandas as pd
# data = pd.DataFrame({'x': ['A','B','C','D','E'],
# 'y': [5, 3, 6, 7, 2]})
# alt.Chart(data).mark_bar().encode(
# x='x',
# y='y',
# )

# %%
import altair as alt
data=alt.Data(values=[{'x': 'A', 'y':5},
                      {'x': 'B', 'y':3},
                      {'x': 'C', 'y':6},
                      {'x': 'D', 'y':7},
                      {'x': 'E', 'y':2}])
alt.Chart(data).mark_bar().encode(
    x='x:O',
    y='y:Q',
#specifyordinaldata
#specifquantitativedata
)
# Out:
# alt.Chart(...)

# %%
import altair as alt 
from vega_datasets import data
url=data.cars.url
alt.Chart(url).mark_point().encode(
x='Horsepower:Q',
y='Miles_per_Gallon:Q' 
)
# Out:
# alt.Chart(...)

# %%
import pandas as pd
import numpy as np
rand = np.random.RandomState(0)
data = pd.DataFrame({'value': rand.randn(100).cumsum()},
index=pd.date_range('2018'
, freq='D'
, periods=100))
data.head()
# Out:
#                value
# 2018-01-01  1.764052
# 2018-01-02  2.164210
# 2018-01-03  3.142948
# 2018-01-04  5.383841
# 2018-01-05  7.251399

# %%
import altair as alt 
alt.Chart(data.reset_index()).mark_line().encode(
x='index:T', y='value:Q' )
# Out:
# alt.Chart(...)

# %%
long_form = pd.DataFrame({'Date': ['2007-10-01','2007-11-01','2007-12-01','2007-10-01','2007-11-01','2007-12-01','2007-10-01','2007-11-01','2007-12-01'],
'company': ['AAPL','AAPL','AAPL','AMZN','AMZN','AMZN','GOOG','GOOG','GOOG'],
'price': [189.95, 182.22, 198.08, 89.15, 90.56, 92.64, 707.00, 693.00, 691.48]})
print(long_form)
# Out:
#          Date company   price
# 0  2007-10-01    AAPL  189.95
# 1  2007-11-01    AAPL  182.22
# 2  2007-12-01    AAPL  198.08
# 3  2007-10-01    AMZN   89.15
# 4  2007-11-01    AMZN   90.56
# 5  2007-12-01    AMZN   92.64
# 6  2007-10-01    GOOG  707.00
# 7  2007-11-01    GOOG  693.00
# 8  2007-12-01    GOOG  691.48

# %%
alt.Chart(long_form).mark_line().encode(
x='Date:T',
y='price:Q',
color='company:N' )
# Out:
# alt.Chart(...)

# %%
wide_form = pd.DataFrame({'Date': ['2007-10-01','2007-11-01','2007-12-01'],
'AAPL': [189.95, 182.22, 198.08],
'AMZN': [89.15, 90.56, 92.64],
'GOOG': [707.00, 693.00, 691.48]})
print(wide_form)
# Out:
#          Date    AAPL   AMZN    GOOG
# 0  2007-10-01  189.95  89.15  707.00
# 1  2007-11-01  182.22  90.56  693.00
# 2  2007-12-01  198.08  92.64  691.48

# %%
wide_form.melt('Date', var_name='company', value_name='price')
# Out:
#          Date company   price
# 0  2007-10-01    AAPL  189.95
# 1  2007-11-01    AAPL  182.22
# 2  2007-12-01    AAPL  198.08
# 3  2007-10-01    AMZN   89.15
# 4  2007-11-01    AMZN   90.56
# 5  2007-12-01    AMZN   92.64
# 6  2007-10-01    GOOG  707.00
# 7  2007-11-01    GOOG  693.00
# 8  2007-12-01    GOOG  691.48

# %%
alt.Chart(wide_form).transform_fold(
    ['AAPL','AMZN','GOOG'],
    as_=['company','price']
).mark_line().encode(
x='Date:T',
y='price:Q',
color='company:N'
)
# Out:
# alt.Chart(...)

# %%
sequedata = alt.sequence(0, 10, 0.1, as_='x')
alt.Chart(data).transform_calculate(
y='sin(datum.x)'
).mark_line().encode(
x='x:Q',
y='y:Q',
)
#sequence generator
# Out:
# alt.Chart(...)

# %%
import altair as alt
data = alt.graticule(step=[15, 15])
alt.Chart(data).mark_geoshape(stroke='red').project(
'orthographic'
,
rotate=[0, -45, 0]
)
# Out:
# alt.Chart(...)

# %%
import altair as alt 
from vega_datasets import data
cars=data.cars()
alt.Chart(cars).mark_point().encode(
x='Horsepower',
y='Miles_per_Gallon',
color='Origin',
shape='Origin' )
# Out:
# alt.Chart(...)

# %%
alt.Chart(cars).mark_point().encode(
x='Acceleration:Q',
y='Miles_per_Gallon:Q',
    color='Origin:N')
# Out:
# alt.Chart(...)

# %%
base = alt.Chart(cars).mark_point().encode(
x='Horsepower:Q',
y='Miles_per_Gallon:Q',
).properties(
width=150,
height=150
)
alt.vconcat(
base.encode(color='Cylinders:Q'),
base.encode(color='Cylinders:O'),
base.encode(color='Cylinders:N'),
)
#short form
# Out:
# alt.VConcatChart(...)

# %%
pop = data.population.url
base = alt.Chart(pop).mark_bar().encode(
alt.Y('mean(people):Q'
, title='total population')
).properties(
width=200,
height=200
)
alt.hconcat(
base.encode(x='year:Q').properties(title='year=quantitative'),
base.encode(x='year:O').properties(title='year=ordinal')
)
# Out:
# alt.HConcatChart(...)

# %%
alt.Chart(cars).mark_bar().encode( alt.X('Horsepower', bin=True), y='count()' )
# Out:
# alt.Chart(...)

# %%
alt.Chart(cars).mark_point().encode( alt.X('Horsepower', bin=True), alt.Y('Miles_per_Gallon', bin=True), size='count()', )
# Out:
# alt.Chart(...)

# %%
alt.Chart(cars).mark_circle().encode(
alt.X('Horsepower',bin=True),
alt.Y('Miles_per_Gallon',bin=True),
size='count()',
color='average(Acceleration):Q' )
# Out:
# alt.Chart(...)

# %%
import altair as alt
from vega_datasets import data
barley = data.barley()
alt.Chart(barley).mark_bar().encode(
x='variety:N'
,
y='sum(yield):Q'
,
color='site:N'
,
order=alt.Order("site"
, sort="ascending")
)
# Out:
# alt.Chart(...)

# %%
import altair as alt
from vega_datasets import data
driving = data.driving()
alt.Chart(driving).mark_line(point=True).encode(
alt.X('miles'
, scale=alt.Scale(zero=False)),
alt.Y('gas'
, scale=alt.Scale(zero=False)),
order='year'
)
# Out:
# alt.Chart(...)

# %%
barley=data.barley()
base=alt.Chart(barley).mark_bar().encode(
y='mean(yield):Q',
color=alt.Color('mean(yield):Q',legend=None)
).properties(width=100,height=100)
#Sortxinascendingorder
ascending=base.encode(
    alt.X(field='site',type='nominal',sort='ascending')
).properties(
title='Ascending' 
)# Sort x in descendingorder
descending=base.encode(alt.X(field='site',type='nominal',sort='descending')
).properties(
    title='Descending' )
#Sortxinanexplicitly-specifiedorder
explicit=base.encode(
    alt.X(field='site',type='nominal',
          sort=['Duluth', 'GrandRapids', 'Morris','UniversityFarm', 'Waseca', 'Crookston'])
).properties(
    title='Explicit' )# Sort according toencodingchannel
sortchannel=base.encode(
    alt.X(field='site',type='nominal',sort='y')
).properties(
title='ByChannel' )# Sort according to anotherfield
sortfield=base.encode(
    alt.X(field='site',type='nominal',
          sort=alt.EncodingSortField(field='yield',op='mean'))
).properties(
    title='ByYield' )

# %%
import altair as alt
from vega_datasets import data

barley = data.barley()

base = alt.Chart(barley).mark_bar().encode(
    y='mean(yield):Q',
    color=alt.Color('mean(yield):Q', legend=None)
).properties(width=100, height=100)

# Sort x in ascending order
ascending = base.encode(
    alt.X(field='site', type='nominal', sort='ascending')
).properties(
    title='Ascending'
)

# Sort x in descending order
descending = base.encode(
    alt.X(field='site', type='nominal', sort='descending')
).properties(
    title='Descending'
)

# Sort x in an explicitly-specified order
explicit = base.encode(
    alt.X(field='site', type='nominal',
          sort=['Duluth', 'Grand Rapids', 'Morris',
                'University Farm', 'Waseca', 'Crookston'])
).properties(
    title='Explicit'
)

# Sort according to encoding channel
sortchannel = base.encode(
    alt.X(field='site', type='nominal',
          sort='y')
).properties(
    title='By Channel'
)

# Sort according to another field
sortfield = base.encode(
    alt.X(field='site', type='nominal',
          sort=alt.EncodingSortField(field='yield', op='mean'))
).properties(
    title='By Yield'
)

alt.concat(
    ascending, descending, explicit,
    sortchannel, sortfield,
    columns=3
)
# Out:
# alt.ConcatChart(...)

# %%
import altair as alt
from vega_datasets import data
seattle_weather = data.seattle_weather()
alt.Chart(seattle_weather).mark_bar().encode(
    alt.X('temp_max', bin=True),
    y='count()',
    color='weather'
)
# Out:
# alt.Chart(...)

# %%
import altair as alt
import altair as alt
import pandas as pd
from vega_datasets import data
seattle_weather = data.seattle_weather()
