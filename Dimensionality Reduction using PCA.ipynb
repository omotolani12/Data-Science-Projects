# %%
from sklearn.datasets import load_breast_cancer
cancer = load_breast_cancer()
import pandas as pd
features_df = pd.DataFrame(cancer.data, columns=cancer.feature_names)
target_df = pd.DataFrame(cancer.target, columns=["breast_cancer"])

# %%
features_df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# ...

# %%
target_df.head()
# Out:
#    breast_cancer
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0

# %%
features_df.shape
# Out:
# (569, 30)

# %%
target_df.shape
# Out:
# (569, 1)

# %%
features_df.describe()
# Out:
#        mean radius  mean texture  mean perimeter    mean area  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        mean smoothness  mean compactness  mean concavity  mean concave points  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %%
from sklearn.preprocessing import StandardScaler
# Standardizing the features
scaler = StandardScaler()
scaler.fit(features_df)
features_df = scaler.transform(features_df)

# %%
features_df = pd.DataFrame(features_df, columns=cancer.feature_names)
.describe()
# Out:
#         mean radius  mean texture  mean perimeter     mean area  \
# count  5.690000e+02  5.690000e+02    5.690000e+02  5.690000e+02
# mean  -3.162867e-15 -6.530609e-15   -7.078891e-16 -8.799835e-16
# std    1.000880e+00  1.000880e+00    1.000880e+00  1.000880e+00
# min   -2.029648e+00 -2.229249e+00   -1.984504e+00 -1.454443e+00
# 25%   -6.893853e-01 -7.259631e-01   -6.919555e-01 -6.671955e-01
# 50%   -2.150816e-01 -1.046362e-01   -2.359800e-01 -2.951869e-01
# 75%    4.693926e-01  5.841756e-01    4.996769e-01  3.635073e-01
# max    3.971288e+00  4.651889e+00    3.976130e+00  5.250529e+00
#
#        mean smoothness  mean compactness  mean concavity  mean concave points  \
# count     5.690000e+02      5.690000e+02    5.690000e+02         5.690000e+02
# mean      6.132177e-15     -1.120369e-15   -4.421380e-16         9.732500e-16
# std       1.000880e+00      1.000880e+00    1.000880e+00         1.000880e+00
# ...

# %%
from sklearn.decomposition import PCA
pca = PCA()
pca.fit(features_df)
# Out:
# PCA()

# %%
import numpy as np

tot_var = np.array(pca.explained_variance_ratio_)
print(tot_var)
# Out:
# [4.42720256e-01 1.89711820e-01 9.39316326e-02 6.60213492e-02
#  5.49576849e-02 4.02452204e-02 2.25073371e-02 1.58872380e-02
#  1.38964937e-02 1.16897819e-02 9.79718988e-03 8.70537901e-03
#  8.04524987e-03 5.23365745e-03 3.13783217e-03 2.66209337e-03
#  1.97996793e-03 1.75395945e-03 1.64925306e-03 1.03864675e-03
#  9.99096464e-04 9.14646751e-04 8.11361259e-04 6.01833567e-04
#  5.16042379e-04 2.72587995e-04 2.30015463e-04 5.29779290e-05
#  2.49601032e-05 4.43482743e-06]

# %%
tot_var.cumsum()
# Out:
# array([0.44272026, 0.63243208, 0.72636371, 0.79238506, 0.84734274,
#        0.88758796, 0.9100953 , 0.92598254, 0.93987903, 0.95156881,
#        0.961366  , 0.97007138, 0.97811663, 0.98335029, 0.98648812,
#        0.98915022, 0.99113018, 0.99288414, 0.9945334 , 0.99557204,
#        0.99657114, 0.99748579, 0.99829715, 0.99889898, 0.99941502,
#        0.99968761, 0.99991763, 0.99997061, 0.99999557, 1.        ])

# %%
pca = PCA(n_components = 5) 
pca.fit(features_df)
features_df_pca = pca.transform(features_df)

# %%
features_df_pca = pd.DataFrame(features_df_pca, columns=["Comp1", "Comp2", "Comp3", "Comp4", "Comp5"])

# %%
df = pd.concat([features_df_pca, target_df], axis=1)
df.head()
# Out:
#       Comp1      Comp2     Comp3     Comp4     Comp5  breast_cancer
# 0  9.192837   1.948583 -1.123166  3.633731 -1.195110              0
# 1  2.387802  -3.768172 -0.529293  1.118264  0.621775              0
# 2  5.733896  -1.075174 -0.551748  0.912083 -0.177086              0
# 3  7.122953  10.275589 -3.232790  0.152547 -2.960878              0
# 4  3.935302  -1.948072  1.389767  2.940639  0.546747              0

# %%
import seaborn as sbn

sbn.pairplot(data=df, hue="breast_cancer")

# %%
features_df_pca.corr()
# Out:
#               Comp1         Comp2         Comp3         Comp4         Comp5
# Comp1  1.000000e+00 -6.068362e-17 -2.398413e-17  1.631265e-16 -5.287094e-17
# Comp2 -6.068362e-17  1.000000e+00  6.515083e-16  1.235894e-14 -3.263102e-14
# Comp3 -2.398413e-17  6.515083e-16  1.000000e+00  1.871230e-14 -4.768644e-14
# Comp4  1.631265e-16  1.235894e-14  1.871230e-14  1.000000e+00 -1.634323e-12
# Comp5 -5.287094e-17 -3.263102e-14 -4.768644e-14 -1.634323e-12  1.000000e+00

# %%
features_df.corr()
# Out:
#                          mean radius  mean texture  mean perimeter  mean area  \
# mean radius                 1.000000      0.323782        0.997855   0.987357
# mean texture                0.323782      1.000000        0.329533   0.321086
# mean perimeter              0.997855      0.329533        1.000000   0.986507
# mean area                   0.987357      0.321086        0.986507   1.000000
# mean smoothness             0.170581     -0.023389        0.207278   0.177028
# mean compactness            0.506124      0.236702        0.556936   0.498502
# mean concavity              0.676764      0.302418        0.716136   0.685983
# mean concave points         0.822529      0.293464        0.850977   0.823269
# mean symmetry               0.147741      0.071401        0.183027   0.151293
# mean fractal dimension     -0.311631     -0.076437       -0.261477  -0.283110
# radius error                0.679090      0.275869        0.691765   0.732562
# ...
